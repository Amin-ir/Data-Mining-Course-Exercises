# %%
import random
import pandas as pd
import math
import statistics as stats
import operator

# %%
generated_ids = []
class Cluster:
    def __init__(self, members, children):
        if members is None:
            members = []
        self.members = members
        if children is None:
            children = []
        self.children = children
        self.id = self.generate_id()
    def generate_id(self):
        id = ''
        possible_chars = '1234567890abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'
        while len(id) == 0 or id in generated_ids:
            id = ''
            for _ in range(0, 20):
                random_char = random.choice(possible_chars)
                id += random_char
        
        generated_ids.append(id)

        return id

# %%
df = pd.read_csv('./datasets/weather_forecast_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  2500 non-null   float64
#  1   Humidity     2500 non-null   float64
#  2   Wind_Speed   2500 non-null   float64
#  3   Cloud_Cover  2500 non-null   float64
#  4   Pressure     2500 non-null   float64
#  5   Rain         2500 non-null   object
# dtypes: float64(5), object(1)
# memory usage: 117.3+ KB

# %%
df.drop(columns=['Rain'], inplace=True)

# %%
def get_euclidean_distance(obj1: pd.Series, obj2: pd.Series):
    result = 0
    for attribute in obj1.keys():
        result += pow(float(obj1[attribute]) - float(obj2[attribute]), 2)

    return math.sqrt(result)

# %%
def get_clusters_distance(c1: Cluster, c2: Cluster, method: str):
    distances = []
    for item in c1.members:
        for _item in c2.members:
            distances.append(get_euclidean_distance(_item, item))
    
    if method == 'max':
        return max(distances)
    if method == 'min':
        return min(distances)
    if method == 'avg':
        return stats.mean(distances)
    
    raise Exception('invalid method passed')

# %%
def generate_distance_matrix(clusters: list, method: str):
    matrix = dict()
    for cluster in clusters:
        for other_cluster in [c for c in clusters if c is not cluster]:
            if f'{cluster.id}|{other_cluster.id}' not in matrix:
                distance = get_clusters_distance(cluster, other_cluster, method)
                matrix[f'{cluster.id}|{other_cluster.id}'] = distance
                matrix[f'{other_cluster.id}|{cluster.id}'] = distance

    return matrix

# %%
def perform_agglomerative_hierarchical_clustering(dataset: pd.DataFrame, method: str):
    clusters = [Cluster([row], []) for i, row in dataset.iterrows()]

    while len(clusters) > 1:
        distance_matrix = generate_distance_matrix(clusters, method)
        closest_clusters = min(distance_matrix.items(), key=operator.itemgetter(1))[0]
        c1_key, c2_key = closest_clusters.split('|')[0], closest_clusters.split('|')[1]
        c1, c2 = next((c for c in clusters if c.id == c1_key), None), next((c for c in clusters if c.id == c2_key), None)
        c1.children.append(c2)
        clusters.remove(c2)

    return clusters[0]

# %%
def series_as_string(serie: pd.Series):
    s = ''
    for attr in serie.keys():
        s += f'"{attr}":{serie[attr]} '

    return s

# %%
def print_hierarchy(node: Cluster, level: int):
    spaces = ''
    for _ in range(0, level):
        spaces += ' '
    print(spaces + f'cluster id: {node.id}; objects: [')
    for member in node.members:
        print(spaces + series_as_string(member))

    print(spaces + ']; internal clusters: ')
    for child in node.children:
        print_hierarchy(child, level + 1)
    print(spaces + ']')

# %%
hierarchy_root = perform_agglomerative_hierarchical_clustering(df[:200], 'max')

# %%
print_hierarchy(hierarchy_root, 0)
# Out:
# cluster id: RpznOEPNWkPB0Ypn8QvR; objects: [
# "Temperature":23.72033759818312 "Humidity":89.59264065174611 "Wind_Speed":7.335604391040214 "Cloud_Cover":50.50169383291316 "Pressure":1032.378758690279
# ]; internal clusters:
#  cluster id: GqBcRCYM4LrY0erOSnkb; objects: [
#  "Temperature":33.355349948119844 "Humidity":94.26030814274029 "Wind_Speed":11.85795524802031 "Cloud_Cover":49.85858788649463 "Pressure":1030.176153553989
#  ]; internal clusters:
#  ]
#  cluster id: hRowuffA3NkWE66Hc4PB; objects: [
#  "Temperature":10.479829957733338 "Humidity":86.95071771557434 "Wind_Speed":16.775945567999454 "Cloud_Cover":49.26848752549474 "Pressure":1029.706512092824
#  ]; internal clusters:
#  ]
#  cluster id: CBczgHzntcAuIySsdJLI; objects: [
#  "Temperature":33.59370196286561 "Humidity":88.37542686178719 "Wind_Speed":2.474866568294325 "Cloud_Cover":62.64242471491316 "Pressure":1036.8236476569737
#  ]; internal clusters:
#   cluster id: 9EBhVX4cVNeQ3KSuNdEC; objects: [
#   "Temperature":31.160216811778195 "Humidity":85.75585790171274 "Wind_Speed":5.3156276517729895 "Cloud_Cover":57.16933663458366 "Pressure":1036.8471602272225
#   ]; internal clusters:
#   ]
#   cluster id: 0LLZg8mg4DpAPqxk9uPv; objects: [
#   "Temperature":33.9020908680806 "Humidity":99.70810023879793 "Wind_Speed":4.515998237809606 "Cloud_Cover":62.71912945576285 "Pressure":1047.9942950178986
#   ]; internal clusters:
#   ]
#  ]
#  cluster id: Kytxzgnw8VW3HXgrvYue; objects: [
#  "Temperature":34.70934595148066 "Humidity":91.86778125111906 "Wind_Speed":9.922193132036146 "Cloud_Cover":44.54133154310441 "Pressure":1043.4199296452794
#  ]; internal clusters:
#  ]
#  cluster id: tJKYH5cQDke5FAgTMgAu; objects: [
#  "Temperature":21.403758305413717 "Humidity":76.35285569909188 "Wind_Speed":13.92496512538619 "Cloud_Cover":41.14567308107999 "Pressure":1026.458643554943
#  ]; internal clusters:
#   cluster id: Xtd0Io0h5wZ7LYjHBkae; objects: [
#   "Temperature":28.25305073791924 "Humidity":82.20346138674299 "Wind_Speed":19.16382742315099 "Cloud_Cover":42.63232854737952 "Pressure":1028.888589908336
#   ]; internal clusters:
#   ]
#   cluster id: TdA2obvbrKoJwg7iMiF8; objects: [
#   "Temperature":26.504338437317127 "Humidity":71.38541997851672 "Wind_Speed":15.019169186989842 "Cloud_Cover":35.92426406226436 "Pressure":1010.4294713467096
#   ]; internal clusters:
#   ]
#  ]
#  cluster id: upSPgRvhTKWT1ktx7ZuO; objects: [
#  "Temperature":11.775901454947174 "Humidity":96.96000891012494 "Wind_Speed":6.377567064219846 "Cloud_Cover":47.33186956586549 "Pressure":1046.4042876128824
#  ]; internal clusters:
#   cluster id: FZ6WjgafB4YdniGAtDAr; objects: [
#   "Temperature":10.46304486151535 "Humidity":97.63547945869152 "Wind_Speed":0.5267711828171473 "Cloud_Cover":57.33787248278139 "Pressure":1049.073009203233
#   ]; internal clusters:
#   ]
#   cluster id: epTlVlEM7ph3qOSjj4Ne; objects: [
#   "Temperature":13.736207616449844 "Humidity":97.4814273303726 "Wind_Speed":11.235004588717292 "Cloud_Cover":36.83432643678146 "Pressure":1031.6760710373514
#   ]; internal clusters:
#   ]
#  ]
#  cluster id: I3c4N15ePOmoHLNYNByU; objects: [
#  "Temperature":13.58383218522616 "Humidity":95.73548495829692 "Wind_Speed":2.1622550340910007 "Cloud_Cover":71.48299959022737 "Pressure":1037.56485351305
#  ]; internal clusters:
#   cluster id: eLuAdk6D6OVi3HmWjmNv; objects: [
#   "Temperature":19.189046751197413 "Humidity":96.75943273741584 "Wind_Speed":17.21353934717378 "Cloud_Cover":63.00614901694244 "Pressure":1039.217244961105
#   ]; internal clusters:
#   ]
#  ]
#  cluster id: x6LNrWbEVwcmoPboPH79; objects: [
#  "Temperature":18.98769751434465 "Humidity":77.82894875121508 "Wind_Speed":1.954974263871032 "Cloud_Cover":29.55552224361168 "Pressure":1046.138477675031
#  ]; internal clusters:
#   cluster id: uGXHalLqBRFNsWu6rdhN; objects: [
#   "Temperature":10.117386904813676 "Humidity":80.0452679243668 "Wind_Speed":7.130690500811689 "Cloud_Cover":34.2547995787465 "Pressure":1039.611508662478
#   ]; internal clusters:
#   ]
#   cluster id: 3rIdhYIUYz1A25TJsHkL; objects: [
#   "Temperature":12.759378529107629 "Humidity":90.09342980212978 "Wind_Speed":6.159662146846672 "Cloud_Cover":24.822925918601 "Pressure":1048.0560884994345
#   ]; internal clusters:
#   ]
#  ]
#  cluster id: 35DOcEkc8VTbMbGnQao2; objects: [
#  "Temperature":28.379850553064877 "Humidity":85.47886171313122 "Wind_Speed":12.443845389808324 "Cloud_Cover":74.22047933730614 "Pressure":1018.1734316085274
#  ]; internal clusters:
#   cluster id: NpxfCnafeY5oF4kcEN3h; objects: [
#   "Temperature":33.60930974959834 "Humidity":82.71296730483229 "Wind_Speed":9.19127432655727 "Cloud_Cover":67.99575134724469 "Pressure":1006.251849398722
#   ]; internal clusters:
#   ]
#   cluster id: CcGhOYlC2Ihq8l168uab; objects: [
#   "Temperature":24.80104828179597 "Humidity":80.12167446185039 "Wind_Speed":5.135132223973981 "Cloud_Cover":82.10120962669403 "Pressure":1027.7849309293858
#   ]; internal clusters:
#    cluster id: cU0R8D04hWIOXsvOS2Z7; objects: [
#    "Temperature":20.89662313164067 "Humidity":85.6676968556931 "Wind_Speed":0.6886257159362841 "Cloud_Cover":84.36475202595983 "Pressure":1030.14802992812
#    ]; internal clusters:
#    ]
#    cluster id: AiAbe8uewKzvjmI4SBQu; objects: [
#    "Temperature":26.099754980740936 "Humidity":87.20740088283583 "Wind_Speed":14.07295216583979 "Cloud_Cover":74.8403055339874 "Pressure":1035.4393309313398
#    ]; internal clusters:
#     cluster id: 7L2jA95oLuhT7kkKMMbY; objects: [
#     "Temperature":17.2519401802611 "Humidity":81.1904966442114 "Wind_Speed":18.588506519632663 "Cloud_Cover":72.76448018535098 "Pressure":1040.6969077794768
#     ]; internal clusters:
#     ]
#    ]
#   ]
#  ]
#  cluster id: loXgJ9JAblkm9U079KuF; objects: [
#  "Temperature":26.147352826666403 "Humidity":48.21726041042326 "Wind_Speed":15.258546760433369 "Cloud_Cover":59.76627863227763 "Pressure":1049.738751014439
#  ]; internal clusters:
#   cluster id: 2Wo91iS94rM2kvYT6NcB; objects: [
#   "Temperature":28.051389986758696 "Humidity":52.25109931094311 "Wind_Speed":16.10330361559138 "Cloud_Cover":61.7529432658452 "Pressure":1048.4710120946452
#   ]; internal clusters:
#   ]
#   cluster id: BNT1Hd7zu5ppRlb7G24C; objects: [
#   "Temperature":16.613890302615673 "Humidity":43.38415379122143 "Wind_Speed":13.864987086041188 "Cloud_Cover":51.55929737435348 "Pressure":1041.1961566883854
#   ]; internal clusters:
#   ]
#   cluster id: qINMyVKwmmvrUjJfhaX5; objects: [
#   "Temperature":15.221918902370868 "Humidity":54.93772242765296 "Wind_Speed":7.9145319764028415 "Cloud_Cover":66.81537597839832 "Pressure":1043.8921018836536
#   ]; internal clusters:
#   ]
#   cluster id: 3w6bE7JF2W2TJ4sRaG5f; objects: [
#   "Temperature":29.453918773746263 "Humidity":49.84904005718227 "Wind_Speed":10.191240572887503 "Cloud_Cover":45.90040227489703 "Pressure":1037.707488191113
#   ]; internal clusters:
#    cluster id: wzFfzojWpnXDuKN23T4Y; objects: [
#    "Temperature":23.08120133666749 "Humidity":52.60349744359363 "Wind_Speed":3.817485617015086 "Cloud_Cover":48.23998127880385 "Pressure":1030.484797865137
#    ]; internal clusters:
#    ]
#   ]
#   cluster id: fmhfJNTcYU9oUmb24UQn; objects: [
#   "Temperature":25.388989107096105 "Humidity":30.75444344539852 "Wind_Speed":6.6939852768736285 "Cloud_Cover":50.97824983290283 "Pressure":1038.9424972725683
#   ]; internal clusters:
#   ]
#   cluster id: 9afK90kLHv0vBrt1MSqo; objects: [
#   "Temperature":24.21084872171621 "Humidity":70.66970730712677 "Wind_Speed":12.26571157202924 "Cloud_Cover":61.55729545542656 "Pressure":1041.7153889946196
#   ]; internal clusters:
#    cluster id: CXUi8Plg53BNhpzhaKZC; objects: [
#    "Temperature":26.68525949909204 "Humidity":66.33692575323045 "Wind_Speed":19.966600855960827 "Cloud_Cover":64.01590204338349 "Pressure":1037.183511152735
#    ]; internal clusters:
#    ]
#    cluster id: 7TPTuGy1e1YSGxuNYtvD; objects: [
#    "Temperature":17.07017406441024 "Humidity":65.53448288024279 "Wind_Speed":9.515458178941232 "Cloud_Cover":58.8129755949194 "Pressure":1035.2417264600558
#    ]; internal clusters:
#    ]
#    cluster id: MrRfDVe6lBqUuayVxvgV; objects: [
#    "Temperature":24.747749408864276 "Humidity":69.90328146649374 "Wind_Speed":2.930809231065325 "Cloud_Cover":53.087141902468375 "Pressure":1040.9624385640802
#    ]; internal clusters:
#    ]
#    cluster id: rr32M0YsGDzerCYWqXt1; objects: [
#    "Temperature":11.729174886378452 "Humidity":75.64090017680299 "Wind_Speed":5.034001118004232 "Cloud_Cover":54.94572519173973 "Pressure":1036.1710056298612
#    ]; internal clusters:
#     cluster id: gEWSddJDX4Oy5fdvEAo9; objects: [
#     "Temperature":10.795973238282697 "Humidity":78.55142185569224 "Wind_Speed":12.840410335389736 "Cloud_Cover":47.531382832000816 "Pressure":1035.9953847228517
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: fiEGaHAcJRNl5hp1nZa4; objects: [
#    "Temperature":24.16503635516438 "Humidity":67.39092144101141 "Wind_Speed":15.902158903166244 "Cloud_Cover":82.60991034111457 "Pressure":1044.5383435923402
#    ]; internal clusters:
#     cluster id: qWnitifaCh6KfonJUcHM; objects: [
#     "Temperature":26.302581750042226 "Humidity":58.66687820627863 "Wind_Speed":17.882177647869327 "Cloud_Cover":77.74135601794165 "Pressure":1041.4438621039235
#     ]; internal clusters:
#     ]
#     cluster id: JPcbgItiWuWM9qsXnxcI; objects: [
#     "Temperature":17.45705814890077 "Humidity":61.32524079847414 "Wind_Speed":15.97420117432447 "Cloud_Cover":88.50501127176501 "Pressure":1038.6935012762328
#     ]; internal clusters:
#      cluster id: afHLKCmsLz55Gl3JcfMl; objects: [
#      "Temperature":15.68536569933308 "Humidity":53.63069627302101 "Wind_Speed":17.575025021323512 "Cloud_Cover":85.56647760152495 "Pressure":1041.7317354593738
#      ]; internal clusters:
#      ]
#     ]
#    ]
#   ]
#   cluster id: zje5GFyIXHLtOAGJcqel; objects: [
#   "Temperature":27.045507477587087 "Humidity":38.42711759162012 "Wind_Speed":11.302946772062697 "Cloud_Cover":80.56069161573312 "Pressure":1039.7254222826552
#   ]; internal clusters:
#    cluster id: fGol39EuUCMkCPu0rJwi; objects: [
#    "Temperature":26.33002049642834 "Humidity":41.096039540627935 "Wind_Speed":9.657354576830317 "Cloud_Cover":74.71868070268448 "Pressure":1046.202995036753
#    ]; internal clusters:
#    ]
#    cluster id: 8BfpbkUnxXLebXNh3eUy; objects: [
#    "Temperature":20.86041563895302 "Humidity":35.33016135410712 "Wind_Speed":0.17273183434094 "Cloud_Cover":93.32279456145662 "Pressure":1048.7548514880168
#    ]; internal clusters:
#    ]
#    cluster id: PEpnd9p0qEpsSrV9iljQ; objects: [
#    "Temperature":16.11063980004007 "Humidity":31.02660746804496 "Wind_Speed":11.649471472047535 "Cloud_Cover":73.86253730248428 "Pressure":1022.3953034134072
#    ]; internal clusters:
#    ]
#   ]
#   cluster id: oe1cyzgN47B2v6ziCd2B; objects: [
#   "Temperature":20.939680281567316 "Humidity":40.79944443606025 "Wind_Speed":2.2325659971252265 "Cloud_Cover":45.82750842102168 "Pressure":1014.1737660638806
#   ]; internal clusters:
#    cluster id: a3BTkaB8e6CwTo2oYs1R; objects: [
#    "Temperature":16.21882858799895 "Humidity":36.45957183643531 "Wind_Speed":3.1678294420277786 "Cloud_Cover":47.19647572483107 "Pressure":1019.8043215910322
#    ]; internal clusters:
#    ]
#    cluster id: fJ8PJwiFfFfZ9csR2Ew1; objects: [
#    "Temperature":25.12113799362615 "Humidity":39.78111060778362 "Wind_Speed":11.184363655504804 "Cloud_Cover":55.63877522380456 "Pressure":1018.332777420299
#    ]; internal clusters:
#     cluster id: diXPbbWlclGrV87xGG8S; objects: [
#     "Temperature":26.94541341990575 "Humidity":40.21635231270592 "Wind_Speed":15.407517726049967 "Cloud_Cover":60.80549794500912 "Pressure":1020.4375189100142
#     ]; internal clusters:
#     ]
#     cluster id: 482bUFfWdaLoq2F1Zn2O; objects: [
#     "Temperature":28.48876987623219 "Humidity":30.41571275781488 "Wind_Speed":9.86122381890442 "Cloud_Cover":51.76827935162682 "Pressure":1017.091854060072
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: PO0ONKBGn2KBO6UCKGDQ; objects: [
#    "Temperature":32.027579927779044 "Humidity":36.487963451071245 "Wind_Speed":9.038980207390308 "Cloud_Cover":46.78472413688216 "Pressure":1007.5934330323696
#    ]; internal clusters:
#    ]
#    cluster id: DM9DLm6FH3EljDp5xAa5; objects: [
#    "Temperature":13.454573783715343 "Humidity":52.05172039802598 "Wind_Speed":10.342791431075703 "Cloud_Cover":37.009635765878265 "Pressure":1022.8310204997988
#    ]; internal clusters:
#     cluster id: Iy2wECGAe44leiWGJcgk; objects: [
#     "Temperature":12.427531894826531 "Humidity":59.47775312216565 "Wind_Speed":5.302504742424096 "Cloud_Cover":26.744524368225207 "Pressure":1018.134510780234
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: 74Ii5lrZFnQWewKnxFaH; objects: [
#    "Temperature":34.4654585558191 "Humidity":51.93943659144392 "Wind_Speed":12.995817134168616 "Cloud_Cover":42.84011694565088 "Pressure":1018.9512813318612
#    ]; internal clusters:
#     cluster id: 47W2ZlTciWiHGRhwPlsY; objects: [
#     "Temperature":24.66282337025208 "Humidity":49.92858464733013 "Wind_Speed":13.817482559233136 "Cloud_Cover":40.06135513846922 "Pressure":1018.180271838826
#     ]; internal clusters:
#      cluster id: jwD8rrCL1N4kmaIMNPfm; objects: [
#      "Temperature":24.430714715104187 "Humidity":50.18440437148342 "Wind_Speed":13.583646654070195 "Cloud_Cover":37.51014129982331 "Pressure":1024.104234934337
#      ]; internal clusters:
#      ]
#     ]
#     cluster id: Fe4NopNKXcAUyY4RXtjS; objects: [
#     "Temperature":34.388037625072144 "Humidity":59.37202544184523 "Wind_Speed":7.09065340131515 "Cloud_Cover":43.18131838784951 "Pressure":1013.250937531762
#     ]; internal clusters:
#     ]
#     cluster id: ePbFutjCrOBCKnUrFIYy; objects: [
#     "Temperature":31.20020573305586 "Humidity":45.43539047510555 "Wind_Speed":19.68803716456676 "Cloud_Cover":42.46977056919615 "Pressure":1011.235161743063
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: OniVYgDtOqNlf0grw891; objects: [
#    "Temperature":12.956860646723332 "Humidity":62.31475529231857 "Wind_Speed":4.019831676312466 "Cloud_Cover":53.30356805066168 "Pressure":1015.0167251589788
#    ]; internal clusters:
#     cluster id: czdMdAeZcJz2eJqxx5tD; objects: [
#     "Temperature":14.999913122410002 "Humidity":61.35146650438118 "Wind_Speed":14.755477150333393 "Cloud_Cover":47.70436210737763 "Pressure":1014.8263442881504
#     ]; internal clusters:
#     ]
#     cluster id: fWq2Fp0FAvJcfCvto8Pt; objects: [
#     "Temperature":22.53310954816756 "Humidity":72.80397267415287 "Wind_Speed":8.600541415040748 "Cloud_Cover":61.34427335030937 "Pressure":1015.3401110036172
#     ]; internal clusters:
#      cluster id: xheuyAA3bAXz9xLlw3kv; objects: [
#      "Temperature":27.43571932861409 "Humidity":65.30704264892776 "Wind_Speed":5.9929260843516 "Cloud_Cover":63.98291539559244 "Pressure":1019.30371765859
#      ]; internal clusters:
#      ]
#     ]
#     cluster id: Vg90st5nqeOiajBT2c86; objects: [
#     "Temperature":20.925798844983536 "Humidity":66.28364512174038 "Wind_Speed":10.941536046129835 "Cloud_Cover":50.01009596293442 "Pressure":1001.2107890724732
#     ]; internal clusters:
#      cluster id: UDZy7YmRLoYJuY14DLra; objects: [
#      "Temperature":24.531821815896468 "Humidity":61.84329908994079 "Wind_Speed":5.541653381874207 "Cloud_Cover":47.716940830353096 "Pressure":993.7769963615224
#      ]; internal clusters:
#      ]
#      cluster id: Qhd5cWBlkd2jPP0iKVzd; objects: [
#      "Temperature":26.765946740453984 "Humidity":73.07963841743684 "Wind_Speed":18.220506256618137 "Cloud_Cover":54.83267785773366 "Pressure":997.6817402746616
#      ]; internal clusters:
#      ]
#      cluster id: TaGFoi5f1XqyK45C4WES; objects: [
#      "Temperature":24.25491926044699 "Humidity":54.72496369411604 "Wind_Speed":2.896059417536172 "Cloud_Cover":52.89325210024439 "Pressure":1001.6494517157278
#      ]; internal clusters:
#      ]
#      cluster id: eYSERqV9whzUVFHKAUvl; objects: [
#      "Temperature":33.81872528792462 "Humidity":62.27658002123501 "Wind_Speed":18.92321727070864 "Cloud_Cover":53.37097117512868 "Pressure":1000.5952457965916
#      ]; internal clusters:
#      ]
#     ]
#     cluster id: tTwcmePu8BSel6wGpstC; objects: [
#     "Temperature":14.654825147008404 "Humidity":62.69759902837474 "Wind_Speed":4.199260604125568 "Cloud_Cover":71.60043512962876 "Pressure":1005.9206864660924
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: Us7opYOcE4BnDhM55qnf; objects: [
#    "Temperature":17.885708773104597 "Humidity":38.05964951235024 "Wind_Speed":1.4289775598418286 "Cloud_Cover":41.21476492229073 "Pressure":989.7191769106928
#    ]; internal clusters:
#     cluster id: 6tf9DCvqifbDPk9Ftw8w; objects: [
#     "Temperature":24.22751846536483 "Humidity":44.58898099414758 "Wind_Speed":1.2395429214839335 "Cloud_Cover":45.79620447204654 "Pressure":997.6656131261694
#     ]; internal clusters:
#     ]
#     cluster id: QHil13hA4QE4S9p8DIon; objects: [
#     "Temperature":13.294946560109803 "Humidity":36.77622534883179 "Wind_Speed":2.2374410367293174 "Cloud_Cover":53.7531451344345 "Pressure":995.5902036064732
#     ]; internal clusters:
#     ]
#    ]
#   ]
#  ]
#  cluster id: 2UKx8psN0AtQYWSbSjKy; objects: [
#  "Temperature":19.58603797064444 "Humidity":82.9782932331459 "Wind_Speed":5.760536586706103 "Cloud_Cover":98.0144498972855 "Pressure":1036.5034571561982
#  ]; internal clusters:
#   cluster id: Hgs4nfK4Xoil28uTiyNS; objects: [
#   "Temperature":29.79312595206661 "Humidity":81.31765126927587 "Wind_Speed":16.92609873392226 "Cloud_Cover":93.92329417135517 "Pressure":1029.4026903671104
#   ]; internal clusters:
#   ]
#   cluster id: puh22LsCfgdV1zQ78FZq; objects: [
#   "Temperature":25.44088742689693 "Humidity":99.53836545759228 "Wind_Speed":4.169966409759411 "Cloud_Cover":92.79200892164285 "Pressure":1042.7034112873944
#   ]; internal clusters:
#    cluster id: 6OXbHHicAdm6WUSIPQrB; objects: [
#    "Temperature":25.15983035319811 "Humidity":94.00792207585197 "Wind_Speed":1.6286367113267608 "Cloud_Cover":98.24770099875552 "Pressure":1036.1995483287585
#    ]; internal clusters:
#     cluster id: YwWxAjxxyHYKpAugvEBU; objects: [
#     "Temperature":25.45038572497104 "Humidity":89.24983147852053 "Wind_Speed":2.142582373627493 "Cloud_Cover":93.67956851643142 "Pressure":1028.8663176769414
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: 09C4fl4QlkzWHfSTx4ce; objects: [
#    "Temperature":11.505636790731746 "Humidity":98.10535320961498 "Wind_Speed":2.3802709441666603 "Cloud_Cover":85.46041335567958 "Pressure":1048.9591211854186
#    ]; internal clusters:
#     cluster id: 7jVpu1MmWFxLS1GjklGp; objects: [
#     "Temperature":13.095499571236038 "Humidity":99.79324409435704 "Wind_Speed":2.6495406576920555 "Cloud_Cover":91.79645340523744 "Pressure":1044.0568574762483
#     ]; internal clusters:
#     ]
#    ]
#   ]
#   cluster id: 2NXtRqEuc2OGKDxnFcby; objects: [
#   "Temperature":10.505459936008142 "Humidity":75.45609114405701 "Wind_Speed":14.79733117529648 "Cloud_Cover":99.14233105026427 "Pressure":1011.5771942728558
#   ]; internal clusters:
#    cluster id: VCH56P3dBDZOOe7E5m0Q; objects: [
#    "Temperature":16.358912044259824 "Humidity":72.64148369808788 "Wind_Speed":18.50312360144465 "Cloud_Cover":98.73976729273946 "Pressure":1023.8112881013932
#    ]; internal clusters:
#    ]
#    cluster id: 6IFOvO2JNfKBUJvkjt7L; objects: [
#    "Temperature":29.355842235855416 "Humidity":72.28188533516568 "Wind_Speed":15.853407039007784 "Cloud_Cover":98.24621044111832 "Pressure":1013.1999442220858
#    ]; internal clusters:
#    ]
#    cluster id: 13yrALOf5PcnjfhSbsmN; objects: [
#    "Temperature":12.968192973856102 "Humidity":82.03381579540653 "Wind_Speed":2.413298907684769 "Cloud_Cover":92.19734138855232 "Pressure":999.528385804197
#    ]; internal clusters:
#     cluster id: rUiKvmGftvzlMpHzgSkO; objects: [
#     "Temperature":13.386851605561256 "Humidity":84.23627000128057 "Wind_Speed":9.034534205067356 "Cloud_Cover":92.0543242221186 "Pressure":1007.2843303942846
#     ]; internal clusters:
#      cluster id: AvpUkzGznEZTxttac3iY; objects: [
#      "Temperature":15.598117201509504 "Humidity":87.8501283720485 "Wind_Speed":1.9791130251583544 "Cloud_Cover":92.32393801200276 "Pressure":1012.6107100077852
#      ]; internal clusters:
#      ]
#     ]
#     cluster id: 44bs9CHleVkD6wieazFw; objects: [
#     "Temperature":14.117353912447818 "Humidity":77.14209384784415 "Wind_Speed":2.8494434995290296 "Cloud_Cover":87.00073629596982 "Pressure":1008.069539401854
#     ]; internal clusters:
#     ]
#     cluster id: D7KQ3WKMDLSThJGRH4Cp; objects: [
#     "Temperature":20.596376213954493 "Humidity":73.20665626327036 "Wind_Speed":4.403570531130021 "Cloud_Cover":93.60706086069423 "Pressure":992.0764492422109
#     ]; internal clusters:
#     ]
#    ]
#   ]
#   cluster id: skDuuwavo5uObfGvpr1a; objects: [
#   "Temperature":12.402460197349075 "Humidity":58.4226111772938 "Wind_Speed":10.303175383626426 "Cloud_Cover":97.46834478583918 "Pressure":1049.7033545199024
#   ]; internal clusters:
#    cluster id: H0yAh4FLDIKR8r7euHZK; objects: [
#    "Temperature":17.539370416863733 "Humidity":64.90475469180282 "Wind_Speed":1.2006572058853004 "Cloud_Cover":94.50078340440056 "Pressure":1043.4058886928888
#    ]; internal clusters:
#    ]
#   ]
#  ]
#  cluster id: 4l2iKFTiXWahk6VOKYhp; objects: [
#  "Temperature":23.622079574922424 "Humidity":74.36775792086564 "Wind_Speed":7.050550632784658 "Cloud_Cover":67.25528206034686 "Pressure":982.6320127095368
#  ]; internal clusters:
#   cluster id: vITFQMPyLJlal7KmpoYm; objects: [
#   "Temperature":23.22237299382261 "Humidity":76.87794305987336 "Wind_Speed":15.825673129009743 "Cloud_Cover":72.86978986682412 "Pressure":980.1089338550744
#   ]; internal clusters:
#   ]
#   cluster id: 7qWoQAExhN9ie3JKZrbr; objects: [
#   "Temperature":30.81549613869845 "Humidity":65.04844693143934 "Wind_Speed":7.681961102168988 "Cloud_Cover":57.03767176214433 "Pressure":980.3486633971628
#   ]; internal clusters:
#   ]
#   cluster id: pOHzOBrRBTjuGQK0a4IL; objects: [
#   "Temperature":24.40393336044592 "Humidity":77.98589033320434 "Wind_Speed":0.1781231978391506 "Cloud_Cover":53.67042533245972 "Pressure":986.397231010479
#   ]; internal clusters:
#   ]
#   cluster id: go4WzzJkHh73hliJCM6a; objects: [
#   "Temperature":27.313289751944147 "Humidity":61.379750282611184 "Wind_Speed":6.158725053507319 "Cloud_Cover":67.69077928446383 "Pressure":992.8782958846728
#   ]; internal clusters:
#   ]
#   cluster id: Bgao933p2vxN01BrZrQy; objects: [
#   "Temperature":29.842442583935515 "Humidity":85.51200670365782 "Wind_Speed":18.54300875294647 "Cloud_Cover":74.92823555021944 "Pressure":982.130171217288
#   ]; internal clusters:
#   ]
#   cluster id: I4ofipPsptBVzuolsYPv; objects: [
#   "Temperature":14.914559042001336 "Humidity":65.04739149283095 "Wind_Speed":7.834293151471428 "Cloud_Cover":82.2684554489393 "Pressure":983.2367145649378
#   ]; internal clusters:
#    cluster id: 8VM8o3eso9J0aWfHnZzL; objects: [
#    "Temperature":14.57978405017792 "Humidity":61.47861012165161 "Wind_Speed":11.375538365976135 "Cloud_Cover":75.60286356710962 "Pressure":992.8283252501764
#    ]; internal clusters:
#    ]
#   ]
#   cluster id: PTz1H3Vs2i7hDtEOYAO7; objects: [
#   "Temperature":21.5369840563233 "Humidity":93.13465428405225 "Wind_Speed":1.4244492228378247 "Cloud_Cover":71.89489921540743 "Pressure":990.9355668250896
#   ]; internal clusters:
#    cluster id: gIxiEVdK1Xwyk8ArOeTs; objects: [
#    "Temperature":34.41902720475843 "Humidity":96.0981874071986 "Wind_Speed":2.715319911777827 "Cloud_Cover":71.00628066747386 "Pressure":985.0486820256598
#    ]; internal clusters:
#    ]
#    cluster id: MSD3geSjRgQ95PLsHDqc; objects: [
#    "Temperature":10.46974501090888 "Humidity":90.87209911995028 "Wind_Speed":9.723241935152904 "Cloud_Cover":76.16533303200376 "Pressure":1001.3261294039288
#    ]; internal clusters:
#     cluster id: SXOX4yfrbzPA11sO6fgT; objects: [
#     "Temperature":19.092769273565565 "Humidity":87.3117359043103 "Wind_Speed":10.72362837024205 "Cloud_Cover":78.43974193260598 "Pressure":1007.0859824501674
#     ]; internal clusters:
#      cluster id: DuxNk3aVAaTMpQmvedoB; objects: [
#      "Temperature":12.551120268700702 "Humidity":89.741453334427 "Wind_Speed":14.528977697146797 "Cloud_Cover":77.42655997733135 "Pressure":1009.8163432855304
#      ]; internal clusters:
#      ]
#     ]
#     cluster id: 84GPlhHywi7v1LKB5mim; objects: [
#     "Temperature":11.603687408719608 "Humidity":80.31709977262793 "Wind_Speed":13.644315052590398 "Cloud_Cover":65.31136838100272 "Pressure":1007.0576657436122
#     ]; internal clusters:
#      cluster id: qVXvkktXwGZE7VRGAr8p; objects: [
#      "Temperature":11.450729008096893 "Humidity":84.31709093169518 "Wind_Speed":14.986737008376537 "Cloud_Cover":66.74442074141515 "Pressure":1006.2105359480367
#      ]; internal clusters:
#      ]
#     ]
#    ]
#   ]
#   cluster id: 6kSDRiJUIpvoqh6QAobj; objects: [
#   "Temperature":34.411486625334895 "Humidity":61.80704086699566 "Wind_Speed":13.910216676155535 "Cloud_Cover":82.27320656705544 "Pressure":983.987085929372
#   ]; internal clusters:
#   ]
#   cluster id: 7W6noz0LLy8ZoTtL5j0Q; objects: [
#   "Temperature":30.9486226874701 "Humidity":48.28532668923951 "Wind_Speed":6.133637243396168 "Cloud_Cover":62.408030164130025 "Pressure":982.8123461281942
#   ]; internal clusters:
#    cluster id: o52bWEbFfSos5xw15Qdn; objects: [
#    "Temperature":17.43592377137834 "Humidity":53.14319499178957 "Wind_Speed":13.151007718300209 "Cloud_Cover":49.06750195610419 "Pressure":985.1770531485316
#    ]; internal clusters:
#     cluster id: w4qW3mNILLTTcRfVarxD; objects: [
#     "Temperature":12.505672182807528 "Humidity":67.87319196884755 "Wind_Speed":1.4156779330544178 "Cloud_Cover":44.19694737134859 "Pressure":983.8122781024264
#     ]; internal clusters:
#     ]
#    ]
#   ]
#   cluster id: 8cse13MDJU3FHuPJyTFR; objects: [
#   "Temperature":20.591369983472617 "Humidity":96.85882241307948 "Wind_Speed":4.6439209259534975 "Cloud_Cover":47.67644427890656 "Pressure":980.8251417426508
#   ]; internal clusters:
#    cluster id: oi7bpXPBm4VwRn2dpA5o; objects: [
#    "Temperature":15.259564026846022 "Humidity":91.50159662674665 "Wind_Speed":11.961746349048845 "Cloud_Cover":41.79132133723797 "Pressure":982.7273620778028
#    ]; internal clusters:
#    ]
#    cluster id: XZqohKo4wOpcnp6ky93M; objects: [
#    "Temperature":25.53696003749409 "Humidity":96.70557561927136 "Wind_Speed":5.782170398608855 "Cloud_Cover":59.22786870825657 "Pressure":986.6613674833178
#    ]; internal clusters:
#    ]
#    cluster id: nkaXx4EQH8z1SkScR7rp; objects: [
#    "Temperature":26.32770813663496 "Humidity":99.04303441011122 "Wind_Speed":13.692287126860244 "Cloud_Cover":53.12465781942654 "Pressure":1000.1864832447952
#    ]; internal clusters:
#     cluster id: N6URSuXDE03EUlBBkKXK; objects: [
#     "Temperature":28.481589484957546 "Humidity":91.78101816125724 "Wind_Speed":17.092996627575076 "Cloud_Cover":49.162786519733736 "Pressure":1004.6272807587908
#     ]; internal clusters:
#     ]
#     cluster id: dqbXOzIqnFxX5eryIdJ6; objects: [
#     "Temperature":27.90818010296414 "Humidity":92.28334950738348 "Wind_Speed":0.0425078963305547 "Cloud_Cover":51.84905463875859 "Pressure":1013.4096156817436
#     ]; internal clusters:
#      cluster id: b0L7aENyRW5w7F4eMnEs; objects: [
#      "Temperature":32.41366489627657 "Humidity":78.25104838086847 "Wind_Speed":2.505939661069887 "Cloud_Cover":44.14519606716867 "Pressure":1017.8813256905678
#      ]; internal clusters:
#      ]
#     ]
#     cluster id: h09QULvEedBcW0ahmPEG; objects: [
#     "Temperature":16.634737273486135 "Humidity":86.15035677914567 "Wind_Speed":19.93764909342883 "Cloud_Cover":41.60064778713563 "Pressure":993.8973884304849
#     ]; internal clusters:
#      cluster id: t6pV65Eqw1K1gBlxtRiX; objects: [
#      "Temperature":24.77181903120433 "Humidity":83.5243107671195 "Wind_Speed":5.565468731423051 "Cloud_Cover":40.97135997466685 "Pressure":997.1854180902884
#      ]; internal clusters:
#       cluster id: YYup59E4z6v1oOZIhsLt; objects: [
#       "Temperature":28.24976406060145 "Humidity":84.9546465382013 "Wind_Speed":9.58069889617592 "Cloud_Cover":42.301876341829306 "Pressure":991.8245503879313
#       ]; internal clusters:
#       ]
#       cluster id: 9RPpoyFRJr5MHrMCD16P; objects: [
#       "Temperature":31.70315143420536 "Humidity":76.3364112521472 "Wind_Speed":4.224124395901933 "Cloud_Cover":39.76572005956746 "Pressure":998.2378789441088
#       ]; internal clusters:
#       ]
#      ]
#      cluster id: y6Jsw6sVw2MEEsi34EDw; objects: [
#      "Temperature":30.34494549256193 "Humidity":89.16665972024575 "Wind_Speed":16.41366719923173 "Cloud_Cover":39.07400058216071 "Pressure":984.7587885509424
#      ]; internal clusters:
#      ]
#     ]
#    ]
#   ]
#   cluster id: xklGcvsrZWzgy1YtV2Li; objects: [
#   "Temperature":33.139915957316525 "Humidity":90.32647652073628 "Wind_Speed":5.771773577200932 "Cloud_Cover":99.91017766569732 "Pressure":987.8037921605496
#   ]; internal clusters:
#    cluster id: nztDTl2FzgxflOFhcWca; objects: [
#    "Temperature":25.3491488991474 "Humidity":85.95139492085917 "Wind_Speed":10.45969330558047 "Cloud_Cover":91.87033173373462 "Pressure":980.8498208432392
#    ]; internal clusters:
#    ]
#   ]
#   cluster id: oH5dK9voUB3ENRHGmSwM; objects: [
#   "Temperature":32.29432501955199 "Humidity":51.848471069719 "Wind_Speed":2.873620839084101 "Cloud_Cover":92.5514972525134 "Pressure":1006.0417334780344
#   ]; internal clusters:
#    cluster id: r38ti80Eu7h7HCFU2wui; objects: [
#    "Temperature":33.6167229262396 "Humidity":45.56614284629671 "Wind_Speed":0.5798973996325296 "Cloud_Cover":95.30194928093334 "Pressure":1011.0086021461362
#    ]; internal clusters:
#     cluster id: zZdceau64FLXQCJAmlvX; objects: [
#     "Temperature":31.39508355981528 "Humidity":43.94597024969254 "Wind_Speed":2.074910859304624 "Cloud_Cover":89.23301730765345 "Pressure":1013.5581606580906
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: G93zoX3Evkzr7Kv9bbwk; objects: [
#    "Temperature":34.09156901252573 "Humidity":48.05711447385431 "Wind_Speed":5.570206017562278 "Cloud_Cover":82.52487276907972 "Pressure":993.7320466194784
#    ]; internal clusters:
#     cluster id: t0CpcEneBuhJrjbwVz4w; objects: [
#     "Temperature":32.987065343616834 "Humidity":51.05088340492482 "Wind_Speed":9.409107087070428 "Cloud_Cover":80.28693878272374 "Pressure":1000.8003179693268
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: U2C07ns9fyuGMqK7zkeL; objects: [
#    "Temperature":25.423349921868923 "Humidity":62.55642489006312 "Wind_Speed":12.732494964166822 "Cloud_Cover":91.14260153205235 "Pressure":999.5947975113892
#    ]; internal clusters:
#     cluster id: NM0rxebcRdpksyIe2ou2; objects: [
#     "Temperature":21.657769321407656 "Humidity":62.95125084686621 "Wind_Speed":16.914792683162588 "Cloud_Cover":97.8407309112806 "Pressure":1005.8890957220998
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: NDE2Ur769KdVMvX1W5Cc; objects: [
#    "Temperature":33.23240493940536 "Humidity":58.76410140086623 "Wind_Speed":14.624653699705425 "Cloud_Cover":75.92362322417372 "Pressure":1020.7393509698336
#    ]; internal clusters:
#     cluster id: I8cz9nAN1NmA8ElsDwzd; objects: [
#     "Temperature":27.59721458850916 "Humidity":51.29404730928084 "Wind_Speed":7.739348143831095 "Cloud_Cover":81.7784653379687 "Pressure":1022.7561322958472
#     ]; internal clusters:
#     ]
#     cluster id: vCQABUZq562inwfy3vls; objects: [
#     "Temperature":33.202032336639775 "Humidity":57.21954401902452 "Wind_Speed":3.46859426523346 "Cloud_Cover":62.78099516269031 "Pressure":1028.4264472104385
#     ]; internal clusters:
#     ]
#     cluster id: ZX7PM2RSH3YTHNL4vr2Q; objects: [
#     "Temperature":17.798624886990048 "Humidity":54.71254733132564 "Wind_Speed":0.0524972016729097 "Cloud_Cover":75.94638594043187 "Pressure":1023.7040628317312
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: o6LJgrJXyKCXh550i5in; objects: [
#    "Temperature":10.979694806358015 "Humidity":35.6144663631055 "Wind_Speed":8.364641727361562 "Cloud_Cover":90.83858070043304 "Pressure":1006.2709889996902
#    ]; internal clusters:
#     cluster id: Fl34rOs7eNx7Y6p7SzWE; objects: [
#     "Temperature":20.785460885849343 "Humidity":35.38110956266658 "Wind_Speed":18.107263406453345 "Cloud_Cover":88.09419204310186 "Pressure":1006.6901619399092
#     ]; internal clusters:
#     ]
#     cluster id: arCVxo1PV3m3zhpCZUQl; objects: [
#     "Temperature":14.062323366909371 "Humidity":34.814449337869064 "Wind_Speed":12.438251795765328 "Cloud_Cover":83.37578807060014 "Pressure":992.5240563917682
#     ]; internal clusters:
#     ]
#     cluster id: z8gleE723wMKEmcFfaeG; objects: [
#     "Temperature":28.13135699549101 "Humidity":31.00444034182451 "Wind_Speed":0.9251695513323744 "Cloud_Cover":91.36999730901168 "Pressure":1000.9114778050164
#     ]; internal clusters:
#     ]
#    ]
#   ]
#  ]
#  cluster id: wOQk2UNRcEg5F12xSjVI; objects: [
#  "Temperature":27.879734159310487 "Humidity":46.48970403534824 "Wind_Speed":5.952483593282764 "Cloud_Cover":4.990052927536981 "Pressure":992.6141895121405
#  ]; internal clusters:
#   cluster id: dZ0zZB4x6ooqrtVb8xEk; objects: [
#   "Temperature":30.182973968125268 "Humidity":51.87939239200243 "Wind_Speed":4.998828309641947 "Cloud_Cover":6.696385261630333 "Pressure":997.114844029909
#   ]; internal clusters:
#   ]
#   cluster id: O6d09ZD2qHLjPNz0TfeL; objects: [
#   "Temperature":31.75030370617048 "Humidity":50.03033227976229 "Wind_Speed":17.76066273065388 "Cloud_Cover":1.978943083306328 "Pressure":1001.5717777961166
#   ]; internal clusters:
#   ]
#   cluster id: 9qxFNOtz8wA3Le31FgpI; objects: [
#   "Temperature":20.719217523644154 "Humidity":34.0723481663698 "Wind_Speed":11.193358597381875 "Cloud_Cover":1.623277738115958 "Pressure":999.116480327906
#   ]; internal clusters:
#   ]
#   cluster id: pc3O3Er9BE07PoM24mO6; objects: [
#   "Temperature":20.36654849976309 "Humidity":33.814870887951386 "Wind_Speed":14.377183570176154 "Cloud_Cover":10.30841611668406 "Pressure":982.1138218417418
#   ]; internal clusters:
#   ]
#   cluster id: 1ohpXXnK3f3wG2xaPXmw; objects: [
#   "Temperature":25.06908440179109 "Humidity":83.07284289257146 "Wind_Speed":1.3719918180799209 "Cloud_Cover":14.855783939243429 "Pressure":1007.2316201172738
#   ]; internal clusters:
#    cluster id: DsS8kiBFOIQSe4xIL6T9; objects: [
#    "Temperature":11.35844970848134 "Humidity":85.12265354266273 "Wind_Speed":5.442917425826666 "Cloud_Cover":7.746912782586235 "Pressure":1001.1961767523868
#    ]; internal clusters:
#    ]
#    cluster id: khaTUteO62k9TMecP5q2; objects: [
#    "Temperature":16.750199329804122 "Humidity":74.2935948774417 "Wind_Speed":7.602598573321089 "Cloud_Cover":22.032209319154276 "Pressure":1020.5180484457208
#    ]; internal clusters:
#     cluster id: pFPL2ueK51VP5VkIP2ki; objects: [
#     "Temperature":23.025915155103235 "Humidity":65.57899625323375 "Wind_Speed":15.623564171369184 "Cloud_Cover":28.62766139163948 "Pressure":1022.4352079404034
#     ]; internal clusters:
#     ]
#     cluster id: zOVS5ThiJOsqS0k1gduY; objects: [
#     "Temperature":10.29285210462505 "Humidity":75.9623569796917 "Wind_Speed":19.6439329218008 "Cloud_Cover":13.383652807049607 "Pressure":1018.7781783038142
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: 8Dby4yIvjS8JEQyt32Ti; objects: [
#    "Temperature":12.178232492538518 "Humidity":67.21240726760512 "Wind_Speed":11.844365499652891 "Cloud_Cover":6.099703563643343 "Pressure":1003.2915258768854
#    ]; internal clusters:
#     cluster id: 99cmZWTc4Ye5WOhwNCmr; objects: [
#     "Temperature":16.332290063494554 "Humidity":66.84251283659319 "Wind_Speed":11.22832416151407 "Cloud_Cover":19.869523899261708 "Pressure":1002.2662313335932
#     ]; internal clusters:
#      cluster id: gJalaGoacsqf2a7riD0f; objects: [
#      "Temperature":15.246093724378053 "Humidity":70.27776281626251 "Wind_Speed":15.126849614842492 "Cloud_Cover":17.11952773615818 "Pressure":1003.533686183473
#      ]; internal clusters:
#      ]
#     ]
#     cluster id: QGldG0bUGrCN0CYtcMoC; objects: [
#     "Temperature":17.9495794848494 "Humidity":59.715383554979496 "Wind_Speed":3.4217743538423395 "Cloud_Cover":8.020519581616114 "Pressure":1013.091003413761
#     ]; internal clusters:
#      cluster id: XRT6NltWk8xpWJ7dMCTS; objects: [
#      "Temperature":14.290741931536012 "Humidity":59.07764702566689 "Wind_Speed":9.600868652078184 "Cloud_Cover":6.03938712493397 "Pressure":1009.0813992665568
#      ]; internal clusters:
#      ]
#      cluster id: 5r4GXK6xZcZKCkqqqzCz; objects: [
#      "Temperature":19.955526555402297 "Humidity":60.4067575854973 "Wind_Speed":9.688373726948583 "Cloud_Cover":15.11504764453302 "Pressure":1010.225378770114
#      ]; internal clusters:
#      ]
#      cluster id: 3oon5LjEB3aAg0Gedv54; objects: [
#      "Temperature":24.398662388904484 "Humidity":58.03573245070538 "Wind_Speed":6.843241651743215 "Cloud_Cover":2.8163609753353414 "Pressure":1023.796086513344
#      ]; internal clusters:
#       cluster id: pv8hBD4daAzfEBuSIWhG; objects: [
#       "Temperature":21.33856706695172 "Humidity":69.03555701447993 "Wind_Speed":7.113484624014925 "Cloud_Cover":5.8904470442266765 "Pressure":1020.413516280162
#       ]; internal clusters:
#       ]
#       cluster id: cyDmgC6xleiNYDUuIEzM; objects: [
#       "Temperature":32.298083875391804 "Humidity":57.28504959509832 "Wind_Speed":1.846985506804244 "Cloud_Cover":9.337831724815803 "Pressure":1029.637345808971
#       ]; internal clusters:
#       ]
#      ]
#     ]
#     cluster id: TNbIFhN6IKy3CwbmhE3X; objects: [
#     "Temperature":27.48698188293761 "Humidity":69.11116935645424 "Wind_Speed":15.317706093986718 "Cloud_Cover":3.2902805759430387 "Pressure":1000.1425451221224
#     ]; internal clusters:
#      cluster id: RjkiGCf6zhFwsrPibPZL; objects: [
#      "Temperature":27.61036004808832 "Humidity":70.60561849275196 "Wind_Speed":7.372335459316483 "Cloud_Cover":6.006829089164412 "Pressure":998.6480080701192
#      ]; internal clusters:
#      ]
#      cluster id: 9Tm4npEuI4yroxIdqOvt; objects: [
#      "Temperature":30.154849726152143 "Humidity":70.90040472038461 "Wind_Speed":19.324416247290007 "Cloud_Cover":11.91581675877671 "Pressure":999.9676022772971
#      ]; internal clusters:
#      ]
#     ]
#     cluster id: U9vzODspxDrfERD20DhR; objects: [
#     "Temperature":17.403504938053622 "Humidity":55.61245017498538 "Wind_Speed":16.176682466321072 "Cloud_Cover":16.496779055647835 "Pressure":991.5987888181104
#     ]; internal clusters:
#      cluster id: LD5X7rQt9eqhqixMWn3N; objects: [
#      "Temperature":12.348512768961042 "Humidity":54.20220915629052 "Wind_Speed":15.82786077515552 "Cloud_Cover":12.863815767692357 "Pressure":995.112524612742
#      ]; internal clusters:
#      ]
#      cluster id: WKBOM19xxoXOb3jyxIiO; objects: [
#      "Temperature":19.912643521174616 "Humidity":61.88054726250833 "Wind_Speed":13.359969520448349 "Cloud_Cover":15.624738243717706 "Pressure":990.4589463569456
#      ]; internal clusters:
#      ]
#      cluster id: 2ikAgm9vZ7xlZAmloeYT; objects: [
#      "Temperature":15.947320534362715 "Humidity":50.39530700381944 "Wind_Speed":16.890890951942698 "Cloud_Cover":8.924627034682198 "Pressure":981.8475201079656
#      ]; internal clusters:
#      ]
#      cluster id: WO6WGzqzG6xiFbEZPr4a; objects: [
#      "Temperature":18.999451611959092 "Humidity":56.16883984814484 "Wind_Speed":2.879434646283064 "Cloud_Cover":20.875950660893228 "Pressure":991.7558166154002
#      ]; internal clusters:
#      ]
#      cluster id: qWheDhIVDDsrG7kbZzJn; objects: [
#      "Temperature":10.502688654687338 "Humidity":40.840859095813535 "Wind_Speed":15.070500696527954 "Cloud_Cover":15.125457180975566 "Pressure":1000.517404831593
#      ]; internal clusters:
#      ]
#     ]
#     cluster id: aRvcDoMC71WjRX5rjlVX; objects: [
#     "Temperature":23.04620804375179 "Humidity":68.74793716267612 "Wind_Speed":7.207011153037306 "Cloud_Cover":4.332054824784537 "Pressure":986.209823950032
#     ]; internal clusters:
#      cluster id: DHrrKawTIkEAzbQiyqIU; objects: [
#      "Temperature":22.26147021543917 "Humidity":60.42427670737354 "Wind_Speed":5.207943154030561 "Cloud_Cover":0.4558070912777268 "Pressure":990.0331056746916
#      ]; internal clusters:
#      ]
#      cluster id: 4k12xRNVeICqR9PVBNUV; objects: [
#      "Temperature":15.577040816015458 "Humidity":65.56310372054907 "Wind_Speed":11.336512849803215 "Cloud_Cover":0.167499407382099 "Pressure":993.2405781880184
#      ]; internal clusters:
#      ]
#      cluster id: 1qN6XJoViOcBNWVqv5LM; objects: [
#      "Temperature":31.65955814821573 "Humidity":72.9922501654689 "Wind_Speed":1.1956887189560383 "Cloud_Cover":13.22736703059394 "Pressure":985.4372637803368
#      ]; internal clusters:
#      ]
#      cluster id: Ij1Q7g0X7lnSGAQfPIek; objects: [
#      "Temperature":25.302393068060532 "Humidity":83.47032895070379 "Wind_Speed":11.37096111713236 "Cloud_Cover":17.701665109231847 "Pressure":981.9272707599382
#      ]; internal clusters:
#       cluster id: WQWeSFRvs7R5dRbALDwZ; objects: [
#       "Temperature":20.35657486286675 "Humidity":86.48659012999336 "Wind_Speed":19.9991322551545 "Cloud_Cover":13.791411041737966 "Pressure":987.9017169099392
#       ]; internal clusters:
#        cluster id: ByGndvQXVwOv6zdwfWZ2; objects: [
#        "Temperature":24.306297644771835 "Humidity":90.35163869294192 "Wind_Speed":15.949438868931775 "Cloud_Cover":11.7947682957816 "Pressure":983.6020017641667
#        ]; internal clusters:
#        ]
#       ]
#       cluster id: L62aG8K08yPo6vifPBMY; objects: [
#       "Temperature":30.72350073043408 "Humidity":84.86856835895486 "Wind_Speed":9.870131035516724 "Cloud_Cover":5.604314037767222 "Pressure":988.666424165076
#       ]; internal clusters:
#        cluster id: WjLTvDSTwsWfRJr2QVP4; objects: [
#        "Temperature":34.05471362793595 "Humidity":84.13325542589209 "Wind_Speed":17.86812053031309 "Cloud_Cover":10.872581326500796 "Pressure":992.9127674774122
#        ]; internal clusters:
#        ]
#        cluster id: pnrkLakLCOEOH6mRy5iO; objects: [
#        "Temperature":32.043384046371315 "Humidity":91.03778773051025 "Wind_Speed":1.112009295385179 "Cloud_Cover":6.788143433830562 "Pressure":996.4515651641248
#        ]; internal clusters:
#         cluster id: qS6SivpP0QgaUuAZLoQE; objects: [
#         "Temperature":27.856032488727784 "Humidity":81.6827329759027 "Wind_Speed":0.9227403946951762 "Cloud_Cover":0.0150381080855521 "Pressure":994.1952206333452
#         ]; internal clusters:
#         ]
#        ]
#       ]
#      ]
#     ]
#    ]
#    cluster id: FehaZQyBuu3o8yCSu18C; objects: [
#    "Temperature":20.96503783655801 "Humidity":98.81468082242873 "Wind_Speed":15.568058688090014 "Cloud_Cover":30.47968906588412 "Pressure":1009.1795471067556
#    ]; internal clusters:
#     cluster id: QOkD3gXcDYtQBma6YHZZ; objects: [
#     "Temperature":20.179582430649997 "Humidity":94.96712407298276 "Wind_Speed":5.576732404006586 "Cloud_Cover":41.10087837148637 "Pressure":1009.132592141822
#     ]; internal clusters:
#      cluster id: gkBSkhwoxCLxqPA8ATXj; objects: [
#      "Temperature":18.633792017422568 "Humidity":96.77443266926092 "Wind_Speed":9.616590087571122 "Cloud_Cover":43.76208941199938 "Pressure":1013.173328813981
#      ]; internal clusters:
#      ]
#     ]
#     cluster id: MC6wod7FMS8WfegLf3ml; objects: [
#     "Temperature":21.71628004119254 "Humidity":98.33913777173828 "Wind_Speed":5.744049242554312 "Cloud_Cover":20.09265169060389 "Pressure":999.0875954033304
#     ]; internal clusters:
#      cluster id: MTw8i03Vs9xZ7scYDLE4; objects: [
#      "Temperature":21.178134465440685 "Humidity":97.5581427443629 "Wind_Speed":10.957481997233586 "Cloud_Cover":15.072507218414543 "Pressure":999.5251852361916
#      ]; internal clusters:
#      ]
#      cluster id: TWgVVWGMfzgHuUQJCZS4; objects: [
#      "Temperature":27.31180298425049 "Humidity":95.99876123477114 "Wind_Speed":10.96104813153421 "Cloud_Cover":22.433741140043484 "Pressure":1001.146163193042
#      ]; internal clusters:
#      ]
#     ]
#    ]
#    cluster id: cd4MyIFqOY0gcx2BW3LA; objects: [
#    "Temperature":29.513229407161383 "Humidity":90.087869383268 "Wind_Speed":3.5203042355582204 "Cloud_Cover":0.7866902523575692 "Pressure":1040.7130729051646
#    ]; internal clusters:
#    ]
#   ]
#   cluster id: JpAZC2UshUuHBztczfWr; objects: [
#   "Temperature":24.201114027348307 "Humidity":45.14653801209415 "Wind_Speed":11.572712664104507 "Cloud_Cover":5.25304210213815 "Pressure":1033.9858671128163
#   ]; internal clusters:
#    cluster id: g26cXMoe7hbndMezJJyh; objects: [
#    "Temperature":25.99802553318809 "Humidity":55.70759887921193 "Wind_Speed":12.462965849045894 "Cloud_Cover":4.371621836509809 "Pressure":1044.7119321839634
#    ]; internal clusters:
#     cluster id: 7hQi1rp9FKZKzJN62Yhz; objects: [
#     "Temperature":26.408239736631835 "Humidity":47.322003025728094 "Wind_Speed":18.630125322351333 "Cloud_Cover":7.812567561224593 "Pressure":1044.8561244447942
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: ScS6nfJ7GL5yeYkcHBas; objects: [
#    "Temperature":29.97896410541809 "Humidity":43.359500291490775 "Wind_Speed":10.711002640838 "Cloud_Cover":18.32707471881192 "Pressure":1044.8620557941772
#    ]; internal clusters:
#     cluster id: HgX4g4CMWWrcr7SrVwyK; objects: [
#     "Temperature":27.44077989818162 "Humidity":42.46461203790029 "Wind_Speed":3.178377820372831 "Cloud_Cover":20.895919013419807 "Pressure":1034.6164909931294
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: v883Fh9IC6ZjYOlAcMOI; objects: [
#    "Temperature":13.004914030329225 "Humidity":41.47369300768358 "Wind_Speed":5.78417024309725 "Cloud_Cover":13.720967479296888 "Pressure":1043.2814080898522
#    ]; internal clusters:
#    ]
#    cluster id: Lqr3xSYsrsQpZpjrstbX; objects: [
#    "Temperature":19.2181292665241 "Humidity":35.04561101530618 "Wind_Speed":10.832845831252351 "Cloud_Cover":6.675554834442066 "Pressure":1018.1715334274892
#    ]; internal clusters:
#     cluster id: kn4LBhuaDlfvFW84Gbg7; objects: [
#     "Temperature":17.96422381128309 "Humidity":37.227725446618216 "Wind_Speed":14.15319455075554 "Cloud_Cover":7.398970375480484 "Pressure":1012.1107004896656
#     ]; internal clusters:
#     ]
#     cluster id: sKRDPc3rSgRRplCFr6a0; objects: [
#     "Temperature":23.39082007562396 "Humidity":44.23496368487184 "Wind_Speed":2.1921802453997885 "Cloud_Cover":7.389422816593028 "Pressure":1021.7669141651854
#     ]; internal clusters:
#     ]
#    ]
#    cluster id: uYbqSg5APdWrZnVJjl8y; objects: [
#    "Temperature":13.223157441371333 "Humidity":65.46821907403745 "Wind_Speed":5.003174444042779 "Cloud_Cover":4.958951320552152 "Pressure":1033.1757143948666
#    ]; internal clusters:
#     cluster id: aQgdorGGLCsoiLCL3hCt; objects: [
#     "Temperature":24.358131221239468 "Humidity":67.76513475192138 "Wind_Speed":0.0293801228474044 "Cloud_Cover":12.291964328588456 "Pressure":1038.539172343128
#     ]; internal clusters:
#     ]
#     cluster id: LZuwJMyoB2WIo5COxM0m; objects: [
#     "Temperature":14.032737947124907 "Humidity":82.9990844466346 "Wind_Speed":14.046454892407212 "Cloud_Cover":11.090324122416128 "Pressure":1036.37806017905
#     ]; internal clusters:
#      cluster id: 591dAKOQnI7PnJ0HSh3o; objects: [
#      "Temperature":13.974239591137993 "Humidity":79.01426381144555 "Wind_Speed":11.562208215596446 "Cloud_Cover":8.100079496575418 "Pressure":1027.184376199892
#      ]; internal clusters:
#      ]
#      cluster id: xYwEi7HWFZK7FA3qCJfE; objects: [
#      "Temperature":24.249122767531624 "Humidity":76.25589922110785 "Wind_Speed":12.469600122093748 "Cloud_Cover":20.548580262251047 "Pressure":1036.5398595866036
#      ]; internal clusters:
#      ]
#     ]
#    ]
#    cluster id: 1l84b3HJgQHisSlAv13f; objects: [
#    "Temperature":26.669167886141693 "Humidity":53.69061938451233 "Wind_Speed":2.262001120276733 "Cloud_Cover":20.457909251008253 "Pressure":1016.8904210578228
#    ]; internal clusters:
#     cluster id: 5Z5keBayK4K8bKpNOwTV; objects: [
#     "Temperature":30.52483074619838 "Humidity":36.27497332691159 "Wind_Speed":2.904842774694749 "Cloud_Cover":16.535719938920312 "Pressure":1008.2548154890944
#     ]; internal clusters:
#      cluster id: j4DK1H3CcJM0PnHzbpEA; objects: [
#      "Temperature":34.971175164196666 "Humidity":48.15390555909178 "Wind_Speed":0.3274030979871911 "Cloud_Cover":11.502807960773351 "Pressure":1007.0910202007792
#      ]; internal clusters:
#      ]
#     ]
#    ]
#    cluster id: cVlVXICka4bfPEMUvj1p; objects: [
#    "Temperature":17.235152323680026 "Humidity":34.32913482563052 "Wind_Speed":14.955689292222456 "Cloud_Cover":29.968502216307435 "Pressure":1048.7692320996234
#    ]; internal clusters:
#    ]
#   ]
#  ]
# ]
